# %%
import pandas as pd
import geopandas as gpd
from geopandas import GeoDataFrame

# for mapping
import folium
from shapely.geometry import Point, Polygon
from keplergl import KeplerGl

# %%
durham_geo = gpd.read_file("geodata/2016_Census_-_Durham_Region_Dissemination_Areas.shp")

# %%
durham_geo.head()
# Out:
#    OBJECTID     DAUID PRUID   PRNAME CDUID  CDNAME CDTYPE   CCSUID CCSNAME  \
# 0     22832  35180133    35  Ontario  3518  Durham     RM  3518013  Oshawa
# 1     22833  35180135    35  Ontario  3518  Durham     RM  3518013  Oshawa
# 2     22834  35180136    35  Ontario  3518  Durham     RM  3518013  Oshawa
# 3     22835  35180137    35  Ontario  3518  Durham     RM  3518013  Oshawa
# 4     22836  35180140    35  Ontario  3518  Durham     RM  3518013  Oshawa
#
#     CSDUID  ... CMAUID CMAPUID CMANAME CMATYPE       CTUID   CTNAME    ADAUID  \
# 0  3518013  ...    532   35532  Oshawa       B  5320009.03  0009.03  35180024
# 1  3518013  ...    532   35532  Oshawa       B  5320008.07  0008.07  35180021
# 2  3518013  ...    532   35532  Oshawa       B  5320008.07  0008.07  35180021
# 3  3518013  ...    532   35532  Oshawa       B  5320008.07  0008.07  35180021
# 4  3518013  ...    532   35532  Oshawa       B  5320008.06  0008.06  35180028
#
#       ShapeSTAre   ShapeSTLen  \
# ...

# %%
durham_geo = durham_geo.to_crs(4326)
durham_geo['lon'] = durham_geo.centroid.x  
durham_geo['lat'] = durham_geo.centroid.y
# Out:
# <ipython-input-27-5aa69be87c17>:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   durham_geo['lon'] = durham_geo.centroid.x
# <ipython-input-27-5aa69be87c17>:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   durham_geo['lat'] = durham_geo.centroid.y

# %%
durham_geo.head()
# Out:
#    OBJECTID     DAUID PRUID   PRNAME CDUID  CDNAME CDTYPE   CCSUID CCSNAME  \
# 0     22832  35180133    35  Ontario  3518  Durham     RM  3518013  Oshawa
# 1     22833  35180135    35  Ontario  3518  Durham     RM  3518013  Oshawa
# 2     22834  35180136    35  Ontario  3518  Durham     RM  3518013  Oshawa
# 3     22835  35180137    35  Ontario  3518  Durham     RM  3518013  Oshawa
# 4     22836  35180140    35  Ontario  3518  Durham     RM  3518013  Oshawa
#
#     CSDUID  ... CMANAME CMATYPE       CTUID   CTNAME    ADAUID     ShapeSTAre  \
# 0  3518013  ...  Oshawa       B  5320009.03  0009.03  35180024  729147.667610
# 1  3518013  ...  Oshawa       B  5320008.07  0008.07  35180021  324255.370850
# 2  3518013  ...  Oshawa       B  5320008.07  0008.07  35180021   97980.547487
# 3  3518013  ...  Oshawa       B  5320008.07  0008.07  35180021   94628.520906
# 4  3518013  ...  Oshawa       B  5320008.06  0008.06  35180028   82415.347422
#
# ...

# %%
durham_geo.to_csv('geodata/durham_spatial.csv')
